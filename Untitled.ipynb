# %%
import pandas as pd

df = pd.read_csv('weather.csv')
print(df)
# Out:
#             年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 0           NaN      NaN      品質情報      均質番号      NaN      品質情報      均質番号
# 1    2019/12/14      9.3         8         1     15.9         8         1
# 2    2019/12/15      7.8         8         1     11.1         8         1
# 3    2019/12/16      6.9         8         1     12.5         8         1
# 4    2019/12/17      8.2         8         1     10.3         8         1
# ..          ...      ...       ...       ...      ...       ...       ...
# 363  2020/12/10      8.7         8         1     11.1         8         1
# 364  2020/12/11      9.2         8         1     13.8         8         1
# 365  2020/12/12     10.4         8         1     14.0         8         1
# 366  2020/12/13      8.6         8         1     14.4         8         1
# 367  2020/12/14      7.8         8         1     12.2         8         1
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# 0        NaN      品質情報      均質番号  ...          均質番号        NaN         品質情報
# 1        3.2         8         1  ...             1        NaN            0
# 2        4.0         8         1  ...             1        NaN            0
# 3        1.3         8         1  ...             1        NaN            0
# 4        5.7         8         1  ...             1        NaN            0
# ..       ...       ...       ...  ...           ...        ...          ...
# 363      6.0         8         1  ...             1        NaN            0
# 364      3.5         8         1  ...             1        NaN            0
# 365      8.0         8         1  ...             1        NaN            0
# 366      4.4         8         1  ...             1        NaN            0
# 367      4.4         8         1  ...             1        NaN            0
#
#      平均蒸気圧(hPa).2 平均風速(m/s) 平均風速(m/s).1  平均風速(m/s).2 日照時間(時間) 日照時間(時間).1  \
# 0            均質番号       NaN        品質情報         均質番号      NaN       品質情報
# 1               1       2.0           8            1      8.9          8
# 2               1       2.3           8            1      6.3          8
# 3               1       1.1           8            1      8.9          8
# 4               1       1.1           8            1      0.2          8
# ..            ...       ...         ...          ...      ...        ...
# 363             1       1.4           8            1      0.0          8
# 364             1       0.8           8            1      4.3          8
# 365             1       1.4           8            1      1.4          8
# 366             1       1.0           8            1      5.5          8
# 367             1       1.9           8            1      4.4          8
#
#      日照時間(時間).2
# 0          均質番号
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 363           1
# 364           1
# 365           1
# 366           1
# 367           1
#
# [368 rows x 28 columns]

# %%
df[:4]
# Out:
#           年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 0         NaN      NaN      品質情報      均質番号      NaN      品質情報      均質番号
# 1  2019/12/14      9.3         8         1     15.9         8         1
# 2  2019/12/15      7.8         8         1     11.1         8         1
# 3  2019/12/16      6.9         8         1     12.5         8         1
#
#    最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# 0      NaN      品質情報      均質番号  ...          均質番号        NaN         品質情報
# 1      3.2         8         1  ...             1        NaN            0
# 2      4.0         8         1  ...             1        NaN            0
# 3      1.3         8         1  ...             1        NaN            0
#
#    平均蒸気圧(hPa).2 平均風速(m/s) 平均風速(m/s).1  平均風速(m/s).2 日照時間(時間) 日照時間(時間).1  \
# 0          均質番号       NaN        品質情報         均質番号      NaN       品質情報
# 1             1       2.0           8            1      8.9          8
# 2             1       2.3           8            1      6.3          8
# 3             1       1.1           8            1      8.9          8
#
#    日照時間(時間).2
# 0        均質番号
# 1           1
# 2           1
# 3           1
#
# [4 rows x 28 columns]

# %%
df.tail(3)
# Out:
#             年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 365  2020/12/12     10.4         8         1     14.0         8         1
# 366  2020/12/13      8.6         8         1     14.4         8         1
# 367  2020/12/14      7.8         8         1     12.2         8         1
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# 365      8.0         8         1  ...             1        NaN            0
# 366      4.4         8         1  ...             1        NaN            0
# 367      4.4         8         1  ...             1        NaN            0
#
#      平均蒸気圧(hPa).2 平均風速(m/s) 平均風速(m/s).1  平均風速(m/s).2 日照時間(時間) 日照時間(時間).1  \
# 365             1       1.4           8            1      1.4          8
# 366             1       1.0           8            1      5.5          8
# 367             1       1.9           8            1      4.4          8
#
#      日照時間(時間).2
# 365           1
# 366           1
# 367           1
#
# [3 rows x 28 columns]

# %%
df[1:]
# Out:
#             年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 1    2019/12/14      9.3         8         1     15.9         8         1
# 2    2019/12/15      7.8         8         1     11.1         8         1
# 3    2019/12/16      6.9         8         1     12.5         8         1
# 4    2019/12/17      8.2         8         1     10.3         8         1
# 5    2019/12/18      9.9         8         1     15.0         8         1
# ..          ...      ...       ...       ...      ...       ...       ...
# 363  2020/12/10      8.7         8         1     11.1         8         1
# 364  2020/12/11      9.2         8         1     13.8         8         1
# 365  2020/12/12     10.4         8         1     14.0         8         1
# 366  2020/12/13      8.6         8         1     14.4         8         1
# 367  2020/12/14      7.8         8         1     12.2         8         1
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# 1        3.2         8         1  ...             1        NaN            0
# 2        4.0         8         1  ...             1        NaN            0
# 3        1.3         8         1  ...             1        NaN            0
# 4        5.7         8         1  ...             1        NaN            0
# 5        4.8         8         1  ...             1        NaN            0
# ..       ...       ...       ...  ...           ...        ...          ...
# 363      6.0         8         1  ...             1        NaN            0
# 364      3.5         8         1  ...             1        NaN            0
# 365      8.0         8         1  ...             1        NaN            0
# 366      4.4         8         1  ...             1        NaN            0
# 367      4.4         8         1  ...             1        NaN            0
#
#      平均蒸気圧(hPa).2 平均風速(m/s) 平均風速(m/s).1  平均風速(m/s).2 日照時間(時間) 日照時間(時間).1  \
# 1               1       2.0           8            1      8.9          8
# 2               1       2.3           8            1      6.3          8
# 3               1       1.1           8            1      8.9          8
# 4               1       1.1           8            1      0.2          8
# 5               1       1.2           8            1      4.3          8
# ..            ...       ...         ...          ...      ...        ...
# 363             1       1.4           8            1      0.0          8
# 364             1       0.8           8            1      4.3          8
# 365             1       1.4           8            1      1.4          8
# 366             1       1.0           8            1      5.5          8
# 367             1       1.9           8            1      4.4          8
#
#      日照時間(時間).2
# 1             1
# 2             1
# 3             1
# 4             1
# 5             1
# ..          ...
# 363           1
# 364           1
# 365           1
# 366           1
# 367           1
#
# [367 rows x 28 columns]

# %%
df.drop(['平均気温(℃).1','平均気温(℃).2'], axis=1)
# Out:
#             年月日  平均気温(℃)  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  最低気温(℃) 最低気温(℃).1  \
# 0           NaN      NaN      NaN      品質情報      均質番号      NaN      品質情報
# 1    2019/12/14      9.3     15.9         8         1      3.2         8
# 2    2019/12/15      7.8     11.1         8         1      4.0         8
# 3    2019/12/16      6.9     12.5         8         1      1.3         8
# 4    2019/12/17      8.2     10.3         8         1      5.7         8
# ..          ...      ...      ...       ...       ...      ...       ...
# 363  2020/12/10      8.7     11.1         8         1      6.0         8
# 364  2020/12/11      9.2     13.8         8         1      3.5         8
# 365  2020/12/12     10.4     14.0         8         1      8.0         8
# 366  2020/12/13      8.6     14.4         8         1      4.4         8
# 367  2020/12/14      7.8     12.2         8         1      4.4         8
#
#     最低気温(℃).2  降水量の合計(mm) 降水量の合計(mm).1  ... 平均雲量(10分比).2  平均蒸気圧(hPa)  \
# 0        均質番号         NaN         品質情報  ...         均質番号         NaN
# 1           1         0.0            8  ...            1         NaN
# 2           1         0.0            8  ...            1         NaN
# 3           1         0.0            8  ...            1         NaN
# 4           1         2.0            8  ...            1         NaN
# ..        ...         ...          ...  ...          ...         ...
# 363         1         0.5            8  ...            1         NaN
# 364         1         0.0            8  ...            1         NaN
# 365         1         0.0            8  ...            1         NaN
# 366         1         0.0            8  ...            1         NaN
# 367         1         0.0            8  ...            1         NaN
#
#     平均蒸気圧(hPa).1 平均蒸気圧(hPa).2  平均風速(m/s) 平均風速(m/s).1 平均風速(m/s).2  日照時間(時間)  \
# 0           品質情報         均質番号        NaN        品質情報        均質番号       NaN
# 1              0            1        2.0           8           1       8.9
# 2              0            1        2.3           8           1       6.3
# 3              0            1        1.1           8           1       8.9
# 4              0            1        1.1           8           1       0.2
# ..           ...          ...        ...         ...         ...       ...
# 363            0            1        1.4           8           1       0.0
# 364            0            1        0.8           8           1       4.3
# 365            0            1        1.4           8           1       1.4
# 366            0            1        1.0           8           1       5.5
# 367            0            1        1.9           8           1       4.4
#
#     日照時間(時間).1 日照時間(時間).2
# 0         品質情報       均質番号
# 1            8          1
# 2            8          1
# 3            8          1
# 4            8          1
# ..         ...        ...
# 363          8          1
# 364          8          1
# 365          8          1
# 366          8          1
# 367          8          1
#
# [368 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['年月日', '平均気温(℃)', '平均気温(℃).1', '平均気温(℃).2', '最高気温(℃)', '最高気温(℃).1',
#        '最高気温(℃).2', '最低気温(℃)', '最低気温(℃).1', '最低気温(℃).2', '降水量の合計(mm)',
#        '降水量の合計(mm).1', '降水量の合計(mm).2', '最深積雪(cm)', '最深積雪(cm).1', '最深積雪(cm).2',
#        '平均雲量(10分比)', '平均雲量(10分比).1', '平均雲量(10分比).2', '平均蒸気圧(hPa)',
#        '平均蒸気圧(hPa).1', '平均蒸気圧(hPa).2', '平均風速(m/s)', '平均風速(m/s).1',
#        '平均風速(m/s).2', '日照時間(時間)', '日照時間(時間).1', '日照時間(時間).2'],
#       dtype='object')

# %%
df[['年月日',
    '平均気温(℃)',
    '最高気温(℃)',
    '最低気温(℃)',
    '降水量の合計(mm)',
    '最深積雪(cm)',
    '平均雲量(10分比)', 
    '平均蒸気圧(hPa)',
    '平均風速(m/s)',
    '日照時間(時間)'
]]
# Out:
#             年月日  平均気温(℃)  最高気温(℃)  最低気温(℃)  降水量の合計(mm)  最深積雪(cm)  平均雲量(10分比)  \
# 0           NaN      NaN      NaN      NaN         NaN       NaN         NaN
# 1    2019/12/14      9.3     15.9      3.2         0.0       NaN         NaN
# 2    2019/12/15      7.8     11.1      4.0         0.0       NaN         NaN
# 3    2019/12/16      6.9     12.5      1.3         0.0       NaN         NaN
# 4    2019/12/17      8.2     10.3      5.7         2.0       NaN         NaN
# ..          ...      ...      ...      ...         ...       ...         ...
# 363  2020/12/10      8.7     11.1      6.0         0.5       NaN         NaN
# 364  2020/12/11      9.2     13.8      3.5         0.0       NaN         NaN
# 365  2020/12/12     10.4     14.0      8.0         0.0       NaN         NaN
# 366  2020/12/13      8.6     14.4      4.4         0.0       NaN         NaN
# 367  2020/12/14      7.8     12.2      4.4         0.0       NaN         NaN
#
#      平均蒸気圧(hPa)  平均風速(m/s)  日照時間(時間)
# 0           NaN        NaN       NaN
# 1           NaN        2.0       8.9
# 2           NaN        2.3       6.3
# 3           NaN        1.1       8.9
# 4           NaN        1.1       0.2
# ..          ...        ...       ...
# 363         NaN        1.4       0.0
# 364         NaN        0.8       4.3
# 365         NaN        1.4       1.4
# 366         NaN        1.0       5.5
# 367         NaN        1.9       4.4
#
# [368 rows x 10 columns]

# %%
df = df[['年月日',
    '平均気温(℃)',
    '最高気温(℃)',
    '最低気温(℃)',
    '降水量の合計(mm)',
    '最深積雪(cm)',
    '平均雲量(10分比)', 
    '平均蒸気圧(hPa)',
    '平均風速(m/s)',
    '日照時間(時間)'
    ]][1:]

# %%
df
# Out:
#             年月日  平均気温(℃)  最高気温(℃)  最低気温(℃)  降水量の合計(mm)  最深積雪(cm)  平均雲量(10分比)  \
# 1    2019/12/14      9.3     15.9      3.2         0.0       NaN         NaN
# 2    2019/12/15      7.8     11.1      4.0         0.0       NaN         NaN
# 3    2019/12/16      6.9     12.5      1.3         0.0       NaN         NaN
# 4    2019/12/17      8.2     10.3      5.7         2.0       NaN         NaN
# 5    2019/12/18      9.9     15.0      4.8         0.0       NaN         NaN
# ..          ...      ...      ...      ...         ...       ...         ...
# 363  2020/12/10      8.7     11.1      6.0         0.5       NaN         NaN
# 364  2020/12/11      9.2     13.8      3.5         0.0       NaN         NaN
# 365  2020/12/12     10.4     14.0      8.0         0.0       NaN         NaN
# 366  2020/12/13      8.6     14.4      4.4         0.0       NaN         NaN
# 367  2020/12/14      7.8     12.2      4.4         0.0       NaN         NaN
#
#      平均蒸気圧(hPa)  平均風速(m/s)  日照時間(時間)
# 1           NaN        2.0       8.9
# 2           NaN        2.3       6.3
# 3           NaN        1.1       8.9
# 4           NaN        1.1       0.2
# 5           NaN        1.2       4.3
# ..          ...        ...       ...
# 363         NaN        1.4       0.0
# 364         NaN        0.8       4.3
# 365         NaN        1.4       1.4
# 366         NaN        1.0       5.5
# 367         NaN        1.9       4.4
#
# [367 rows x 10 columns]

# %%
df.dtypes
# Out:
# 年月日            object
# 平均気温(℃)       float64
# 最高気温(℃)       float64
# 最低気温(℃)       float64
# 降水量の合計(mm)    float64
# 最深積雪(cm)      float64
# 平均雲量(10分比)    float64
# 平均蒸気圧(hPa)    float64
# 平均風速(m/s)     float64
# 日照時間(時間)      float64
# dtype: object

# %%
df.shape
# Out:
# (367, 10)

# %%
df.columns
# Out:
# Index(['年月日', '平均気温(℃)', '最高気温(℃)', '最低気温(℃)', '降水量の合計(mm)', '最深積雪(cm)',
#        '平均雲量(10分比)', '平均蒸気圧(hPa)', '平均風速(m/s)', '日照時間(時間)'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=1, stop=368, step=1)

# %%
df.iloc[4:10,3:6]
# Out:
#     最低気温(℃)  降水量の合計(mm)  最深積雪(cm)
# 5       4.8         0.0       NaN
# 6       7.9         1.0       NaN
# 7       5.7         0.0       NaN
# 8       6.5         0.0       NaN
# 9       4.2        21.0       NaN
# 10      3.6         9.5       NaN

# %%
df_people = pd.read_csv('people.csv')
df_people
# Out:
#    age  id      name nationality
# 0   26  13  Imanishi       Japan
# 1   21  33      Mike     America
# 2   35  31    Suzuki       Japan
# 3   16  20      John     America
# 4   28  11       Kim       Korea

# %%
df_people[df_people['nationality'] == 'America']
# Out:
#    age  id  name nationality
# 1   21  33  Mike     America
# 3   16  20  John     America

# %%
df_people['nationality'].isin(['America'])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: nationality, dtype: bool

# %%
df_people[(df_people['age'] >= 20) & (df_people['age'] < 30)]
# Out:
#    age  id      name nationality
# 0   26  13  Imanishi       Japan
# 1   21  33      Mike     America
# 4   28  11       Kim       Korea

# %%
df_people['age'].unique()
# Out:
# array([26, 21, 35, 16, 28])
