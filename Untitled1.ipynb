# %%
import pandas as pd
df_people = pd.read_csv('people.csv')
df_people
# Out:
#    age  id      name nationality
# 0   26  13  Imanishi       Japan
# 1   21  33      Mike     America
# 2   35  31    Suzuki       Japan
# 3   16  20      John     America
# 4   28  11       Kim       Korea

# %%
df_people.drop_duplicates(inplace=True)

# %%
print(df_people)
# Out:
#    age  id      name nationality
# 0   26  13  Imanishi       Japan
# 1   21  33      Mike     America
# 2   35  31    Suzuki       Japan
# 3   16  20      John     America
# 4   28  11       Kim       Korea

# %%
df_people.drop_duplicates(subset='nationality')
# Out:
#    age  id      name nationality
# 0   26  13  Imanishi       Japan
# 1   21  33      Mike     America
# 4   28  11       Kim       Korea

# %%
df = pd.read_csv('weather.csv')

# %%
df
# Out:
#             年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 0           NaN      NaN      品質情報      均質番号      NaN      品質情報      均質番号
# 1    2019/12/14      9.3         8         1     15.9         8         1
# 2    2019/12/15      7.8         8         1     11.1         8         1
# 3    2019/12/16      6.9         8         1     12.5         8         1
# 4    2019/12/17      8.2         8         1     10.3         8         1
# ..          ...      ...       ...       ...      ...       ...       ...
# 363  2020/12/10      8.7         8         1     11.1         8         1
# 364  2020/12/11      9.2         8         1     13.8         8         1
# 365  2020/12/12     10.4         8         1     14.0         8         1
# 366  2020/12/13      8.6         8         1     14.4         8         1
# 367  2020/12/14      7.8         8         1     12.2         8         1
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# ...

# %%
df.rename(columns={'平均気温(℃)':'平均気温'})
# Out:
#             年月日  平均気温 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 0           NaN   NaN      品質情報      均質番号      NaN      品質情報      均質番号
# 1    2019/12/14   9.3         8         1     15.9         8         1
# 2    2019/12/15   7.8         8         1     11.1         8         1
# 3    2019/12/16   6.9         8         1     12.5         8         1
# 4    2019/12/17   8.2         8         1     10.3         8         1
# ..          ...   ...       ...       ...      ...       ...       ...
# 363  2020/12/10   8.7         8         1     11.1         8         1
# 364  2020/12/11   9.2         8         1     13.8         8         1
# 365  2020/12/12  10.4         8         1     14.0         8         1
# 366  2020/12/13   8.6         8         1     14.4         8         1
# 367  2020/12/14   7.8         8         1     12.2         8         1
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# ...

# %%
df.columns = ['年月日', 
              '平均気温', 
              '最高気温', 
              '最低気温', 
              '降水量の合計', 
              '最深積雪', 
              '平均雲量', 
              '平均蒸気圧', 
              '平均風速', 
              '日照時間']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df.columns = ['年月日',
#       2               '平均気温',
#       3               '最高気温',
#       4               '最低気温',
#       5               '降水量の合計',
#       6               '最深積雪',
#       7               '平均雲量',
#       8               '平均蒸気圧',
#       9               '平均風速',
#      10               '日照時間']
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
df
# Out:
#             年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 0           NaN      NaN      品質情報      均質番号      NaN      品質情報      均質番号
# 1    2019/12/14      9.3         8         1     15.9         8         1
# 2    2019/12/15      7.8         8         1     11.1         8         1
# 3    2019/12/16      6.9         8         1     12.5         8         1
# 4    2019/12/17      8.2         8         1     10.3         8         1
# ..          ...      ...       ...       ...      ...       ...       ...
# 363  2020/12/10      8.7         8         1     11.1         8         1
# 364  2020/12/11      9.2         8         1     13.8         8         1
# 365  2020/12/12     10.4         8         1     14.0         8         1
# 366  2020/12/13      8.6         8         1     14.4         8         1
# 367  2020/12/14      7.8         8         1     12.2         8         1
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# ...

# %%
df = df.sort_values('平均気温(℃)', ascending=False)

# %%
df
# Out:
#            年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 246  2020/8/15     31.2         8         1     36.5         8         1
# 248  2020/8/17     30.9         8         1     37.2         8         1
# 244  2020/8/13     30.4         8         1     37.1         8         1
# 243  2020/8/12     30.3         8         1     35.9         8         1
# 260  2020/8/29     30.0         8         1     34.3         8         1
# ..         ...      ...       ...       ...      ...       ...       ...
# 59   2020/2/10      3.6         8         1      8.8         8         1
# 58    2020/2/9      3.1         8         1      7.5         8         1
# 55    2020/2/6      2.3         8         1      5.5         8         1
# 56    2020/2/7      1.8         8         1      7.0         8         1
# 0          NaN      NaN      品質情報      均質番号      NaN      品質情報      均質番号
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# ...

# %%
pd.get_dummies(df_people, columns=['nationality'])
# Out:
#    age  id      name  nationality_America  nationality_Japan  \
# 0   26  13  Imanishi                    0                  1
# 1   21  33      Mike                    1                  0
# 2   35  31    Suzuki                    0                  1
# 3   16  20      John                    1                  0
# 4   28  11       Kim                    0                  0
#
#    nationality_Korea
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1

# %%
df.isnull()
# Out:
#        年月日  平均気温(℃)  平均気温(℃).1  平均気温(℃).2  最高気温(℃)  最高気温(℃).1  最高気温(℃).2  \
# 246  False    False      False      False    False      False      False
# 248  False    False      False      False    False      False      False
# 244  False    False      False      False    False      False      False
# 243  False    False      False      False    False      False      False
# 260  False    False      False      False    False      False      False
# ..     ...      ...        ...        ...      ...        ...        ...
# 59   False    False      False      False    False      False      False
# 58   False    False      False      False    False      False      False
# 55   False    False      False      False    False      False      False
# 56   False    False      False      False    False      False      False
# 0     True     True      False      False     True      False      False
#
#      最低気温(℃)  最低気温(℃).1  最低気温(℃).2  ...  平均雲量(10分比).2  平均蒸気圧(hPa)  \
# ...

# %%
df.fillna(0)
# Out:
#            年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 246  2020/8/15     31.2         8         1     36.5         8         1
# 248  2020/8/17     30.9         8         1     37.2         8         1
# 244  2020/8/13     30.4         8         1     37.1         8         1
# 243  2020/8/12     30.3         8         1     35.9         8         1
# 260  2020/8/29     30.0         8         1     34.3         8         1
# ..         ...      ...       ...       ...      ...       ...       ...
# 59   2020/2/10      3.6         8         1      8.8         8         1
# 58    2020/2/9      3.1         8         1      7.5         8         1
# 55    2020/2/6      2.3         8         1      5.5         8         1
# 56    2020/2/7      1.8         8         1      7.0         8         1
# 0            0      0.0      品質情報      均質番号      0.0      品質情報      均質番号
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# ...

# %%
df.fillna({'平均蒸気圧(hPa)': '100'})
# Out:
#            年月日  平均気温(℃) 平均気温(℃).1 平均気温(℃).2  最高気温(℃) 最高気温(℃).1 最高気温(℃).2  \
# 246  2020/8/15     31.2         8         1     36.5         8         1
# 248  2020/8/17     30.9         8         1     37.2         8         1
# 244  2020/8/13     30.4         8         1     37.1         8         1
# 243  2020/8/12     30.3         8         1     35.9         8         1
# 260  2020/8/29     30.0         8         1     34.3         8         1
# ..         ...      ...       ...       ...      ...       ...       ...
# 59   2020/2/10      3.6         8         1      8.8         8         1
# 58    2020/2/9      3.1         8         1      7.5         8         1
# 55    2020/2/6      2.3         8         1      5.5         8         1
# 56    2020/2/7      1.8         8         1      7.0         8         1
# 0          NaN      NaN      品質情報      均質番号      NaN      品質情報      均質番号
#
#      最低気温(℃) 最低気温(℃).1 最低気温(℃).2  ...  平均雲量(10分比).2 平均蒸気圧(hPa) 平均蒸気圧(hPa).1  \
# ...

# %%
df.dropna(axis=1)
# Out:
#     平均気温(℃).1 平均気温(℃).2 最高気温(℃).1 最高気温(℃).2 最低気温(℃).1 最低気温(℃).2 降水量の合計(mm).1  \
# 246         8         1         8         1         8         1            8
# 248         8         1         8         1         8         1            8
# 244         8         1         8         1         8         1            8
# 243         8         1         8         1         8         1            8
# 260         8         1         8         1         8         1            8
# ..        ...       ...       ...       ...       ...       ...          ...
# 59          8         1         8         1         8         1            8
# 58          8         1         8         1         8         1            8
# 55          8         1         8         1         8         1            8
# 56          8         1         8         1         8         1            8
# 0        品質情報      均質番号      品質情報      均質番号      品質情報      均質番号         品質情報
#
# ...
